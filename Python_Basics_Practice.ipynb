# %% [markdown]
# <a href="https://colab.research.google.com/github/Menaka-v/Python-Practices/blob/main/Python_Basics_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Basic Python

# %%
#1.Write a Python program to print "Hello, Python!".

print("Hello,Python!")
# Out:
# Hello,Python!

# %%
#2.Store your name, age, and city in variables and display them.

name='Menaka'
age=20
city='Tiruppur'

print("Hello Myself",name,"!","I'm",age,"years old","& I live in",city)
# Out:
# Hello Myself Menaka ! I'm 20 years old & I live in Tiruppur

# %%
#3.Take two numbers from the user and display their sum.

print("SUM OF 2 NUMBERS")

num1=int(input("enter the 1st number : "))
num2=int(input("enter the 2nd number : "))

sum=num1+num2

print("Total =",sum)
# Out:
# SUM OF 2 NUMBERS
# enter the 1st number : 2
# enter the 2nd number : 7
# Total = 9

# %%
#4.Take two numbers and display their addition, subtraction, multiplication, and division.

num1=int(input("Enter 1st number : "))
num2=int(input("Enter 2nd number : "))

sum=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2

print("Sum            =",sum)
print("Subraction     =",sub)
print("Multiplication =",mul)
print("Division       =",div)
# Out:
# Enter 1st number : 2
# Enter 2nd number : 7
#
# Sum            = 9
# Subraction     = -5
# Multiplication = 14
# Division       = 0.2857142857142857

# %%
#5.Write a program to calculate the area of a rectangle.

width=int(input("Enter the width of the rectangle :"))
length=int(input("Enter the length of the rectangle :"))

area=width*length

print("The area of rectangle is =",area)
# Out:
# Enter the width of the rectangle :5
# Enter the length of the rectangle :2
# The area of rectangle is = 10

# %%
#6.Write a program to calculate the area of a circle.

radius=int(input("Enter the radius of circle :"))

area=3.14*radius**2

print("The area of circle is =",area)
# Out:
# Enter the radius of circle :5
# The area of circle is = 78.5

# %%
#7.Write a program to convert Celsius into Fahrenheit.

c=int(input("Enter the Celsius temperature : "))

f=(c*9/5)+32

print("The fahrenheit of",c,"°C is =",f,"°F")
# Out:
# Enter the Celsius temperature : 13
# The fahrenheit of 13 °C is = 55.4 °F

# %%
#8.Take a student's name and marks and display the details.

name=input("Enter student name : ")
mark=int(input("Enter marks : "))

print("The student name is",name)
print("Mark =",mark)
# Out:
# Enter student name : menaka
# Enter marks : 55
# The student name is menaka
# Mark = 55

# %%
#9.Write a program to calculate Simple Interest using Principal, Rate, and Time.

p=int(input("enter the principal amount : "))
r=int(input("enter the rate of interest (in %) : "))
t=int(input("enter the time (in years) : "))

si=p*r*t/100

print("Simple Interest =",si)
# Out:
# enter the principal amount : 20000
# enter the rate of interest (in %) : 10
# enter the time (in years) : 2
# Simple Interest = 4000.0

# %%
#10.Write a program to swap the values of two variables.

a=10
b=20
a,b=b,a

print(a)
print(b)
# Out:
# 20
# 10
